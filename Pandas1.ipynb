# %%
import pandas as pd

# %%
df = pd.read_csv("gapminder.tsv", sep='\t')
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.shape)
# Out:
# (1704, 6)

# %%
print(df.columns)
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
print(df.dtypes)
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
country_df = df['country']
print(country_df.head())
print(country_df.tail())
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object
# 1699    Zimbabwe
# 1700    Zimbabwe
# 1701    Zimbabwe
# 1702    Zimbabwe
# 1703    Zimbabwe
# Name: country, dtype: object

# %%
continent_df = df['continent']
print(continent_df.head())
print(continent_df.tail())
# Out:
# 0    Asia
# 1    Asia
# 2    Asia
# 3    Asia
# 4    Asia
# Name: continent, dtype: object
# 1699    Africa
# 1700    Africa
# 1701    Africa
# 1702    Africa
# 1703    Africa
# Name: continent, dtype: object

# %%
year_df = df['year']
print(year_df.head())
print(year_df.tail())
# Out:
# 0    1952
# 1    1957
# 2    1962
# 3    1967
# 4    1972
# Name: year, dtype: int64
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, dtype: int64

# %%
lifeExp_df = df['lifeExp']
print(lifeExp_df.head())
print(lifeExp_df.tail())
# Out:
# 0    28.801
# 1    30.332
# 2    31.997
# 3    34.020
# 4    36.088
# Name: lifeExp, dtype: float64
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: lifeExp, dtype: float64

# %%
pop_df = df['pop']
print(pop_df.head())
print(pop_df.tail())
# Out:
# 0     8425333
# 1     9240934
# 2    10267083
# 3    11537966
# 4    13079460
# Name: pop, dtype: int64
# 1699     9216418
# 1700    10704340
# 1701    11404948
# 1702    11926563
# 1703    12311143
# Name: pop, dtype: int64

# %%
gdp_df = df['gdpPercap']
print(gdp_df.head())
print(gdp_df.tail())
# Out:
# 0    779.445314
# 1    820.853030
# 2    853.100710
# 3    836.197138
# 4    739.981106
# Name: gdpPercap, dtype: float64
# 1699    706.157306
# 1700    693.420786
# 1701    792.449960
# 1702    672.038623
# 1703    469.709298
# Name: gdpPercap, dtype: float64

# %%
#calling columns by dot
print(df.country.head(1))
print(df.gdpPercap.head(1))
print(df.lifeExp.head(1))
# Out:
# 0    Afghanistan
# Name: country, dtype: object
# 0    779.445314
# Name: gdpPercap, dtype: float64
# 0    28.801
# Name: lifeExp, dtype: float64

# %%
print(df.continent.head(1))
print(df.year.head(1))
# Out:
# 0    Asia
# Name: continent, dtype: object
# 0    1952
# Name: year, dtype: int64

# %%
subset = df[['country', 'year', 'lifeExp']]
print(subset.head())
print(subset.tail())
# Out:
#        country  year  lifeExp
# 0  Afghanistan  1952   28.801
# 1  Afghanistan  1957   30.332
# 2  Afghanistan  1962   31.997
# 3  Afghanistan  1967   34.020
# 4  Afghanistan  1972   36.088
#        country  year  lifeExp
# 1699  Zimbabwe  1987   62.351
# 1700  Zimbabwe  1992   60.377
# 1701  Zimbabwe  1997   46.809
# 1702  Zimbabwe  2002   39.989
# 1703  Zimbabwe  2007   43.487

# %%
subset = df.iloc[:,[3,5,1]]
subset
# Out:
#       lifeExp   gdpPercap continent
# 0      28.801  779.445314      Asia
# 1      30.332  820.853030      Asia
# 2      31.997  853.100710      Asia
# 3      34.020  836.197138      Asia
# 4      36.088  739.981106      Asia
# ...       ...         ...       ...
# 1699   62.351  706.157306    Africa
# 1700   60.377  693.420786    Africa
# 1701   46.809  792.449960    Africa
# 1702   39.989  672.038623    Africa
# 1703   43.487  469.709298    Africa
#
# [1704 rows x 3 columns]

# %%
df.iloc[:,[0,-1]]
# Out:
#           country   gdpPercap
# 0     Afghanistan  779.445314
# 1     Afghanistan  820.853030
# 2     Afghanistan  853.100710
# 3     Afghanistan  836.197138
# 4     Afghanistan  739.981106
# ...           ...         ...
# 1699     Zimbabwe  706.157306
# 1700     Zimbabwe  693.420786
# 1701     Zimbabwe  792.449960
# 1702     Zimbabwe  672.038623
# 1703     Zimbabwe  469.709298
#
# [1704 rows x 2 columns]

# %%
df = pd.read_csv("gapminder.tsv", sep='\t')

small_range = list(range(3, 6)) 
subset = df.iloc[: ,small_range] 
print(subset.head())
# Out:
#    lifeExp       pop   gdpPercap
# 0   28.801   8425333  779.445314
# 1   30.332   9240934  820.853030
# 2   31.997  10267083  853.100710
# 3   34.020  11537966  836.197138
# 4   36.088  13079460  739.981106

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.loc[0:3]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %%
df.iloc[99]
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
#get the last row
number_of_rows = df.shape[0]
print(number_of_rows)
last_row_index = number_of_rows - 1
print(df.loc[last_row_index])
# Out:
# 1704
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
#or use
df.tail(n=1)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
print(df.loc[0])
print(type(df.loc[0]))
print(df.head(n=1))
print(type(df.head(n=1)))
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object
# <class 'pandas.core.series.Series'>
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314
# <class 'pandas.core.frame.DataFrame'>

# %%
#subsetting multiple rows
print(df.loc[[0,99,999]])
print(type(df.loc[[0,99,999]]))
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.iloc[[0,99,999]])
print(type(df.iloc[[0,99,999]]))
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130
# <class 'pandas.core.frame.DataFrame'>

# %%
df.iloc[[0,99,999],[0,2,4]]
# Out:
#          country  year       pop
# 0    Afghanistan  1952   8425333
# 99    Bangladesh  1967  62821884
# 999     Mongolia  1967   1149500

# %%
df.loc[[0,99,999], ['country', 'year', 'pop']]
# Out:
#          country  year       pop
# 0    Afghanistan  1952   8425333
# 99    Bangladesh  1967  62821884
# 999     Mongolia  1967   1149500

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
print(df.groupby('year')['lifeExp'].mean())
#df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
print(df.groupby('country')['lifeExp'].mean())
#df.groupby('country')['lifeExp'].mean()
# Out:
# country
# Afghanistan           37.478833
# Albania               68.432917
# Algeria               59.030167
# Angola                37.883500
# Argentina             69.060417
#                         ...
# Vietnam               57.479500
# West Bank and Gaza    60.328667
# Yemen, Rep.           46.780417
# Zambia                45.996333
# Zimbabwe              52.663167
# Name: lifeExp, Length: 142, dtype: float64

# %%
print(df.groupby('country')['pop'].mean())
#df.groupby('country')['pop'].mean()
# Out:
# country
# Afghanistan           1.582372e+07
# Albania               2.580249e+06
# Algeria               1.987541e+07
# Angola                7.309390e+06
# Argentina             2.860224e+07
#                           ...
# Vietnam               5.456857e+07
# West Bank and Gaza    1.848606e+06
# Yemen, Rep.           1.084319e+07
# Zambia                6.353805e+06
# Zimbabwe              7.641966e+06
# Name: pop, Length: 142, dtype: float64

# %%
grouped_year_df = df.groupby('year')
print(grouped_year_df)
print(type(grouped_year_df))
# Out:
# ...
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
grouped_year_df_lifeExp = grouped_year_df['lifeExp']
print(grouped_year_df_lifeExp)

# %%
mean_lifeExp_by_year = grouped_year_df_lifeExp.mean()
print(mean_lifeExp_by_year)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby(['year', 'continent'])['lifeExp', 'gdpPercap'].mean()
# Out:
# /var/folders/q6/g7092d4n0qd1jz1vdnn2st200000gn/T/ipykernel_4091/1148819723.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['year', 'continent'])['lifeExp', 'gdpPercap'].mean()
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# ...

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df.groupby('continent')['country'].value_counts()
# Out:
# continent  country
# Africa     Algeria           12
#            Angola            12
#            Benin             12
#            Botswana          12
#            Burkina Faso      12
#                              ..
# Europe     Switzerland       12
#            Turkey            12
#            United Kingdom    12
# Oceania    Australia         12
#            New Zealand       12
# Name: country, Length: 142, dtype: int64

# %%
global_yearly_life_expectancy = df.groupby('year')['lifeExp'].mean()
print(global_yearly_life_expectancy)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
global_yearly_life_expectancy.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
s = pd.Series(['banana', 42])
print(type(s))
s
# Out:
# <class 'pandas.core.series.Series'>
# 0    banana
# 1        42
# dtype: object

# %%
s = pd.Series(['Wes McKinney', 'Creator of Pandas'], index=['Person', 'who'])
s
# Out:
# Person         Wes McKinney
# who       Creator of Pandas
# dtype: object

# %%
scientists = pd.DataFrame({'Name': ['Rosaline Franklin', 'William Gosset'],
 'Occupation': ['Chemist', 'Statistician'],  'Born': ['1920-07-25', '1876-06-13'],
'Died': ['1958-04-16', '1937-10-16'],
 'Age': [37, 61]})
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
scientists = pd.DataFrame({
    'Occupation': ['Chemist', 'Statistician'],  'Born': ['1920-07-25', '1876-06-13'],
'Died': ['1958-04-16', '1937-10-16'],
 'Age': [37, 61]}, index=['Rosaline Franklin', 'William Gosset']
)

# %%
scientists
# Out:
#                      Occupation        Born        Died  Age
# Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# William Gosset     Statistician  1876-06-13  1937-10-16   61

# %%
first_scientist  = scientists.loc['Rosaline Franklin']
print(first_scientist)
print(first_scientist.index)
print("values are: " ,first_scientist.values)
print(first_scientist.keys())
# Out:
# Occupation       Chemist
# Born          1920-07-25
# Died          1958-04-16
# Age                   37
# Name: Rosaline Franklin, dtype: object
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')
# values are:  ['Chemist' '1920-07-25' '1958-04-16' 37]
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %%
second_scientist = scientists.loc['William Gosset']
print(second_scientist)
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Died            1937-10-16
# Age                     61
# Name: William Gosset, dtype: object

# %%
ages = scientists['Age']
print(ages)
# Out:
# Rosaline Franklin    37
# William Gosset       61
# Name: Age, dtype: int64

# %%
print(ages.mean())
print(ages.max())
print(ages.min())
print(ages.std())
# Out:
# 49.0
# 61
# 37
# 16.97056274847714

# %%
df[df['year'] < 1980]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1693     Zimbabwe    Africa  1957   50.469   3646340  518.764268
# 1694     Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695     Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696     Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697     Zimbabwe    Africa  1977   57.674   6642107  685.587682
#
# [852 rows x 6 columns]

# %%
df['pop'].mean()
# Out:
# 29601212.324530516

# %%
df['pop'].describe()
# Out:
# count    1.704000e+03
# mean     2.960121e+07
# std      1.061579e+08
# min      6.001100e+04
# 25%      2.793664e+06
# 50%      7.023596e+06
# 75%      1.958522e+07
# max      1.318683e+09
# Name: pop, dtype: float64

# %%
# Out:
# 29601212.324530516

# %%
df[df['pop'] > df['pop'].mean()]
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 34        Algeria    Africa  2002   70.994  31287142  5288.040382
# 35        Algeria    Africa  2007   72.301  33333216  6223.367465
# 55      Argentina  Americas  1987   70.774  31620918  9139.671389
# 56      Argentina  Americas  1992   71.868  33958947  9308.418710
# ...           ...       ...   ...      ...       ...          ...
# 1651      Vietnam      Asia  1987   62.820  62826491   820.799445
# 1652      Vietnam      Asia  1992   67.662  69940728   989.023149
# 1653      Vietnam      Asia  1997   70.672  76048996  1385.896769
# 1654      Vietnam      Asia  2002   73.017  80908147  1764.456677
# 1655      Vietnam      Asia  2007   74.249  85262356  2441.576404
#
# [307 rows x 6 columns]

# %%
print(type(df['pop']> df['pop'].mean()))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#Vectors with integers (scalars)
print(df['lifeExp'].head())
# Out:
# 0    28.801
# 1    30.332
# 2    31.997
# 3    34.020
# 4    36.088
# Name: lifeExp, dtype: float64

# %%
lifeExpPlus10 = df['lifeExp'] + 10
lifeExpPlus10.head()
# Out:
# 0    38.801
# 1    40.332
# 2    41.997
# 3    44.020
# 4    46.088
# Name: lifeExp, dtype: float64

# %%
lifeExpPlus10 - df['lifeExp']
# Out:
# 0       10.0
# 1       10.0
# 2       10.0
# 3       10.0
# 4       10.0
#         ...
# 1699    10.0
# 1700    10.0
# 1701    10.0
# 1702    10.0
# 1703    10.0
# Name: lifeExp, Length: 1704, dtype: float64

# %%
lifeExp_1 = df['lifeExp']
reverselifeExp = lifeExp_1.sort_index(ascending=False)
reverselifeExp
# Out:
# 1703    43.487
# 1702    39.989
# 1701    46.809
# 1700    60.377
# 1699    62.351
#          ...
# 4       36.088
# 3       34.020
# 2       31.997
# 1       30.332
# 0       28.801
# Name: lifeExp, Length: 1704, dtype: float64

# %%
df['pop']
# Out:
# 0        8425333
# 1        9240934
# 2       10267083
# 3       11537966
# 4       13079460
#           ...
# 1699     9216418
# 1700    10704340
# 1701    11404948
# 1702    11926563
# 1703    12311143
# Name: pop, Length: 1704, dtype: int64

# %%
person = pd.read_csv('survey_person.csv') 
site = pd.read_csv('survey_site.csv') 
survey = pd.read_csv('survey_survey.csv') 
visited = pd.read_csv('survey_visited.csv')

# %%
print(site)
print(visited)
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
visited_subset = visited.iloc[[0,2,6],]
visited_subset
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 2    734   DR-3  1939-01-07
# 6    837  MSK-4  1932-01-14

# %%
print(site)
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
o2o_merge = site.merge(visited_subset, left_on='name', right_on='site')
o2o_merge
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
m2o_merge = site.merge(visited, left_on="name", right_on="site")
m2o_merge
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-1 -49.85 -128.57    622   DR-1  1927-02-10
# 2   DR-1 -49.85 -128.57    844   DR-1  1932-03-22
# 3   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 4   DR-3 -47.15 -126.72    735   DR-3  1930-01-12
# 5   DR-3 -47.15 -126.72    751   DR-3  1930-02-26
# 6   DR-3 -47.15 -126.72    752   DR-3         NaN
# 7  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
#many to many
person
# Out:
#       ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth

# %%
survey
# Out:
#     taken person quant  reading
# 0     619   dyer   rad     9.82
# 1     619   dyer   sal     0.13
# 2     622   dyer   rad     7.80
# 3     622   dyer   sal     0.09
# 4     734     pb   rad     8.41
# 5     734   lake   sal     0.05
# 6     734     pb  temp   -21.50
# 7     735     pb   rad     7.22
# 8     735    NaN   sal     0.06
# 9     735    NaN  temp   -26.00
# 10    751     pb   rad     4.35
# 11    751     pb  temp   -18.50
# 12    751   lake   sal     0.10
# 13    752   lake   rad     2.19
# 14    752   lake   sal     0.09
# 15    752   lake  temp   -16.00
# 16    752    roe   sal    41.60
# 17    837   lake   rad     1.46
# 18    837   lake   sal     0.21
# 19    837    roe   sal    22.50
# 20    844    roe   rad    11.25

# %%
ps = person.merge(survey, left_on='ident', right_on='person')
vs = visited.merge(survey, left_on='ident', right_on='taken')
print(ps.head(2))
print(vs.head(2))
# Out:
#   ident personal family  taken person quant  reading
# 0  dyer  William   Dyer    619   dyer   rad     9.82
# 1  dyer  William   Dyer    619   dyer   sal     0.13
#    ident  site       dated  taken person quant  reading
# 0    619  DR-1  1927-02-08    619   dyer   rad     9.82
# 1    619  DR-1  1927-02-08    619   dyer   sal     0.13

# %%
ps_vs = ps.merge(vs, left_on=['ident','taken', 'quant', 'reading'], right_on=['person', 'ident', 'quant', 'reading'])
ps_vs[0:1]
# Out:
#   ident_x personal family  taken_x person_x quant  reading  ident_y  site  \
# 0    dyer  William   Dyer      619     dyer   rad     9.82      619  DR-1
#
#         dated  taken_y person_y
# 0  1927-02-08      619     dyer

# %%
visited_file = pd.read_csv("survey_visited.csv", keep_default_na= False)
visited_file
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
visited_file = pd.read_csv("survey_visited.csv",na_values=[''], keep_default_na= False)
visited_file
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
vs = visited.merge(survey, left_on= 'ident', right_on='taken')
vs['dated'].fillna('', inplace=True)
vs
# Out:
#     ident   site       dated  taken person quant  reading
# 0     619   DR-1  1927-02-08    619   dyer   rad     9.82
# 1     619   DR-1  1927-02-08    619   dyer   sal     0.13
# 2     622   DR-1  1927-02-10    622   dyer   rad     7.80
# 3     622   DR-1  1927-02-10    622   dyer   sal     0.09
# 4     734   DR-3  1939-01-07    734     pb   rad     8.41
# 5     734   DR-3  1939-01-07    734   lake   sal     0.05
# 6     734   DR-3  1939-01-07    734     pb  temp   -21.50
# 7     735   DR-3  1930-01-12    735     pb   rad     7.22
# 8     735   DR-3  1930-01-12    735    NaN   sal     0.06
# 9     735   DR-3  1930-01-12    735    NaN  temp   -26.00
# 10    751   DR-3  1930-02-26    751     pb   rad     4.35
# 11    751   DR-3  1930-02-26    751     pb  temp   -18.50
# 12    751   DR-3  1930-02-26    751   lake   sal     0.10
# 13    752   DR-3                752   lake   rad     2.19
# 14    752   DR-3                752   lake   sal     0.09
# ...

# %%
vms = visited.merge(survey, left_on= 'ident', right_on='taken')
vms['dated'].fillna(method='ffill', inplace= True)
vms
# Out:
#     ident   site       dated  taken person quant  reading
# 0     619   DR-1  1927-02-08    619   dyer   rad     9.82
# 1     619   DR-1  1927-02-08    619   dyer   sal     0.13
# 2     622   DR-1  1927-02-10    622   dyer   rad     7.80
# 3     622   DR-1  1927-02-10    622   dyer   sal     0.09
# 4     734   DR-3  1939-01-07    734     pb   rad     8.41
# 5     734   DR-3  1939-01-07    734   lake   sal     0.05
# 6     734   DR-3  1939-01-07    734     pb  temp   -21.50
# 7     735   DR-3  1930-01-12    735     pb   rad     7.22
# 8     735   DR-3  1930-01-12    735    NaN   sal     0.06
# 9     735   DR-3  1930-01-12    735    NaN  temp   -26.00
# 10    751   DR-3  1930-02-26    751     pb   rad     4.35
# 11    751   DR-3  1930-02-26    751     pb  temp   -18.50
# 12    751   DR-3  1930-02-26    751   lake   sal     0.10
# 13    752   DR-3  1930-02-26    752   lake   rad     2.19
# 14    752   DR-3  1930-02-26    752   lake   sal     0.09
# ...

# %%
vms1 = visited.merge(survey, left_on= 'ident', right_on='taken')
vms1['dated'].fillna(method='ffill', limit=1,inplace= True)
vms1
# Out:
#     ident   site       dated  taken person quant  reading
# 0     619   DR-1  1927-02-08    619   dyer   rad     9.82
# 1     619   DR-1  1927-02-08    619   dyer   sal     0.13
# 2     622   DR-1  1927-02-10    622   dyer   rad     7.80
# 3     622   DR-1  1927-02-10    622   dyer   sal     0.09
# 4     734   DR-3  1939-01-07    734     pb   rad     8.41
# 5     734   DR-3  1939-01-07    734   lake   sal     0.05
# 6     734   DR-3  1939-01-07    734     pb  temp   -21.50
# 7     735   DR-3  1930-01-12    735     pb   rad     7.22
# 8     735   DR-3  1930-01-12    735    NaN   sal     0.06
# 9     735   DR-3  1930-01-12    735    NaN  temp   -26.00
# 10    751   DR-3  1930-02-26    751     pb   rad     4.35
# 11    751   DR-3  1930-02-26    751     pb  temp   -18.50
# 12    751   DR-3  1930-02-26    751   lake   sal     0.10
# 13    752   DR-3  1930-02-26    752   lake   rad     2.19
# 14    752   DR-3         NaN    752   lake   sal     0.09
# ...

# %%
print(vms1.iloc[range(10,20,)])
# Out:
#     ident   site       dated  taken person quant  reading
# 10    751   DR-3  1930-02-26    751     pb   rad     4.35
# 11    751   DR-3  1930-02-26    751     pb  temp   -18.50
# 12    751   DR-3  1930-02-26    751   lake   sal     0.10
# 13    752   DR-3  1930-02-26    752   lake   rad     2.19
# 14    752   DR-3         NaN    752   lake   sal     0.09
# 15    752   DR-3         NaN    752   lake  temp   -16.00
# 16    752   DR-3         NaN    752    roe   sal    41.60
# 17    837  MSK-4  1932-01-14    837   lake   rad     1.46
# 18    837  MSK-4  1932-01-14    837   lake   sal     0.21
# 19    837  MSK-4  1932-01-14    837    roe   sal    22.50

# %%
gapminder = pd.read_csv('gapminder.tsv', sep='\t')
life_exp = gapminder.groupby(['year'])['lifeExp'].mean()

# %%
print(life_exp)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
y2000 = life_exp[life_exp > 2000]
print(y2000)
# Out:
# Series([], Name: lifeExp, dtype: float64)

# %%
ebola = pd.read_csv('country_timeseries.csv')
print(ebola.count())
# Out:
# Date                   122
# Day                    122
# Cases_Guinea            93
# Cases_Liberia           83
# Cases_SierraLeone       87
# Cases_Nigeria           38
# Cases_Senegal           25
# Cases_UnitedStates      18
# Cases_Spain             16
# Cases_Mali              12
# Deaths_Guinea           92
# Deaths_Liberia          81
# Deaths_SierraLeone      87
# Deaths_Nigeria          38
# Deaths_Senegal          22
# Deaths_UnitedStates     18
# Deaths_Spain            16
# Deaths_Mali             12
# dtype: int64

# %%
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
num_rows = ebola.shape[0]
print(num_rows)
num_cols = ebola.shape[1]
print(num_cols)
print(ebola.shape)
# Out:
# 122
# 18
# (122, 18)

# %%
num_rows = ebola.shape[0]
num_missing = num_rows - ebola.count() 
print(num_missing)
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
import numpy as np
print(np.count_nonzero(ebola.isnull()))
# Out:
# 1214

# %%
print(np.count_nonzero(ebola['Cases_Guinea'].isnull()))
# Out:
# 29

# %%
print(ebola.Cases_Guinea.value_counts(dropna=False).head())
# Out:
# NaN      29
# 86.0      3
# 495.0     2
# 112.0     2
# 390.0     2
# Name: Cases_Guinea, dtype: int64

# %%
print(ebola.Cases_Guinea.value_counts(dropna=True).head())
# Out:
# 86.0     3
# 495.0    2
# 112.0    2
# 390.0    2
# 408.0    1
# Name: Cases_Guinea, dtype: int64

# %%
ebola.fillna(0).iloc[0:10,0:5]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0            0.0            10030.0
# 1    1/4/2015  288        2775.0            0.0             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           0.0         8157.0                0.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0            0.0             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0            0.0             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0

# %%
ebola.Cases_Liberia.fillna(method='bfill').iloc[0:10][['Date','Cases_Guinea', 'Cases_Liberia']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/q6/g7092d4n0qd1jz1vdnn2st200000gn/T/ipykernel_4091/3613502640.py in <module>
# ----> 1 ebola.Cases_Liberia.iloc[0:10][['Date','Cases_Guinea', 'Cases_Liberia']]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     982             return self._get_values(key)
#     983
# --> 984         return self._get_with(key)
#     985
#     986     def _get_with(self, key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_with(self, key)
#    1022
#    1023         # handle the dup indexing case GH#4246
# -> 1024         return self.loc[key]
#    1025
#    1026     def _get_values_tuple(self, key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     965
# ...

# %%
ebola3Col = ebola.iloc[0:5][['Date','Cases_Guinea', 'Cases_Liberia']]
ebola3Col.fillna('', inplace=True)
ebola3Col
# Out:
#          Date Cases_Guinea Cases_Liberia
# 0    1/5/2015       2776.0
# 1    1/4/2015       2775.0
# 2    1/3/2015       2769.0        8166.0
# 3    1/2/2015                     8157.0
# 4  12/31/2014       2730.0        8115.0

# %%
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
print(ebola.fillna(method='bfill').iloc[:, 0:5].tail())
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117  3/27/2014    5         103.0            8.0                6.0
# 118  3/26/2014    4          86.0            NaN                NaN
# 119  3/25/2014    3          86.0            NaN                NaN
# 120  3/24/2014    2          86.0            NaN                NaN
# 121  3/22/2014    0          49.0            NaN                NaN
